# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import pmdarima as pmd
import statsmodels.api as sm
from sklearn.ensemble import RandomForestRegressor

# %%
data=pd.read_csv("../train_IxoE5JN.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94992 entries, 0 to 94991
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   row_id    94992 non-null  int64
#  1   datetime  94992 non-null  object
#  2   energy    93092 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
data.head()
# Out:
#    row_id             datetime       energy
# 0       1  2008-03-01 00:00:00  1259.985563
# 1       2  2008-03-01 01:00:00  1095.541500
# 2       3  2008-03-01 02:00:00  1056.247500
# 3       4  2008-03-01 03:00:00  1034.742000
# 4       5  2008-03-01 04:00:00  1026.334500

# %%
data.datetime=pd.to_datetime(data.datetime,yearfirst=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94992 entries, 0 to 94991
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   row_id    94992 non-null  int64
#  1   datetime  94992 non-null  datetime64[ns]
#  2   energy    93092 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 2.2 MB

# %%
data.head()
# Out:
#    row_id            datetime       energy
# 0       1 2008-03-01 00:00:00  1259.985563
# 1       2 2008-03-01 01:00:00  1095.541500
# 2       3 2008-03-01 02:00:00  1056.247500
# 3       4 2008-03-01 03:00:00  1034.742000
# 4       5 2008-03-01 04:00:00  1026.334500

# %%
data.set_index('datetime', inplace=True)

# %%
data.drop('row_id', axis=1, inplace=True)

# %%
data.isna().sum()
# Out:
# energy    1900
# dtype: int64

# %%
data=data.fillna(method='bfill')

# %%
plt.figure(figsize=(20,9))
sns.lineplot(data)
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
data.tail()
# Out:
#                         energy
# datetime
# 2018-12-31 19:00:00  2528.4468
# 2018-12-31 20:00:00  2461.8836
# 2018-12-31 21:00:00  2365.9944
# 2018-12-31 22:00:00  2342.9428
# 2018-12-31 23:00:00  2180.2176

# %%
sm.tsa.graphics.plot_acf(data, zero=False, lags=48)
plt.show()

# %%
sm.tsa.graphics.plot_pacf(data,lags=48, zero=False)
plt.show()
# Out:
# /home/catalyst/anaconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
additive=sm.tsa.seasonal_decompose(data,model="additive" )
additive.plot()
plt.show()

# %%
multiplicative=sm.tsa.seasonal_decompose(data,model="multiplicative" )
additive.plot()
plt.show()

# %%
data["hour"]=data.index.hour
data["month"]=data.index.month
data["dow"]=data.index.day_of_week
data["doy"]=data.index.day_of_year

# %%
data.head(48)
# Out:
#                           energy  hour  month  dow  doy
# datetime
# 2008-03-01 00:00:00  1259.985563     0      3    5   61
# 2008-03-01 01:00:00  1095.541500     1      3    5   61
# 2008-03-01 02:00:00  1056.247500     2      3    5   61
# 2008-03-01 03:00:00  1034.742000     3      3    5   61
# 2008-03-01 04:00:00  1026.334500     4      3    5   61
# 2008-03-01 05:00:00  1033.768500     5      3    5   61
# 2008-03-01 06:00:00  1086.780000     6      3    5   61
# 2008-03-01 07:00:00  1211.742000     7      3    5   61
# 2008-03-01 08:00:00  1293.693000     8      3    5   61
# 2008-03-01 09:00:00  1318.915500     9      3    5   61
# 2008-03-01 10:00:00  1337.943000    10      3    5   61
# 2008-03-01 11:00:00  1348.917000    11      3    5   61
# 2008-03-01 12:00:00  1360.687500    12      3    5   61
# 2008-03-01 13:00:00  1363.254000    13      3    5   61
# 2008-03-01 14:00:00  1385.467500    14      3    5   61
# 2008-03-01 15:00:00  1392.901500    15      3    5   61
# 2008-03-01 16:00:00  1392.901500    16      3    5   61
# 2008-03-01 17:00:00  1384.494000    17      3    5   61
# 2008-03-01 18:00:00  1358.740500    18      3    5   61
# 2008-03-01 19:00:00  1330.509000    19      3    5   61
# 2008-03-01 20:00:00  1346.173500    20      3    5   61
# 2008-03-01 21:00:00  1358.386500    21      3    5   61
# 2008-03-01 22:00:00  1313.074500    22      3    5   61
# 2008-03-01 23:00:00  1244.929500    23      3    5   61
# 2008-03-02 00:00:00  1163.509500     0      3    6   62
# 2008-03-02 01:00:00  1085.010000     1      3    6   62
# 2008-03-02 02:00:00  1032.972000     2      3    6   62
# 2008-03-02 03:00:00  1004.652000     3      3    6   62
# 2008-03-02 04:00:00   989.164500     4      3    6   62
# 2008-03-02 05:00:00   986.067000     5      3    6   62
# 2008-03-02 06:00:00  1002.793500     6      3    6   62
# 2008-03-02 07:00:00  1050.141000     7      3    6   62
# 2008-03-02 08:00:00  1096.249500     8      3    6   62
# 2008-03-02 09:00:00  1163.244000     9      3    6   62
# 2008-03-02 10:00:00  1213.512000    10      3    6   62
# 2008-03-02 11:00:00  1246.257000    11      3    6   62
# 2008-03-02 12:00:00  1246.080000    12      3    6   62
# 2008-03-02 13:00:00  1243.956000    13      3    6   62
# 2008-03-02 14:00:00  1233.159000    14      3    6   62
# 2008-03-02 15:00:00  1217.583000    15      3    6   62
# 2008-03-02 16:00:00  1201.741500    16      3    6   62
# 2008-03-02 17:00:00  1205.370000    17      3    6   62
# 2008-03-02 18:00:00  1193.245500    18      3    6   62
# 2008-03-02 19:00:00  1184.041500    19      3    6   62
# 2008-03-02 20:00:00  1223.512500    20      3    6   62
# 2008-03-02 21:00:00  1243.956000    21      3    6   62
# 2008-03-02 22:00:00  1240.327500    22      3    6   62
# 2008-03-02 23:00:00  1145.190000    23      3    6   62

# %%
x_train=data[:"2017-12-31"]
x_test=data["2018-1-1":]

# %%
x_train
# Out:
#                           energy  hour  month  dow  doy
# datetime
# 2008-03-01 00:00:00  1259.985563     0      3    5   61
# 2008-03-01 01:00:00  1095.541500     1      3    5   61
# 2008-03-01 02:00:00  1056.247500     2      3    5   61
# 2008-03-01 03:00:00  1034.742000     3      3    5   61
# 2008-03-01 04:00:00  1026.334500     4      3    5   61
# ...                          ...   ...    ...  ...  ...
# 2017-12-31 19:00:00  1942.416000    19     12    6  365
# 2017-12-31 20:00:00  1894.776800    20     12    6  365
# 2017-12-31 21:00:00  1868.062000    21     12    6  365
# 2017-12-31 22:00:00  1857.928800    22     12    6  365
# 2017-12-31 23:00:00  1764.229600    23     12    6  365
#
# [86232 rows x 5 columns]

# %%
x_test
# Out:
#                         energy  hour  month  dow  doy
# datetime
# 2018-01-01 00:00:00  1642.7628     0      1    0    1
# 2018-01-01 01:00:00  1463.6552     1      1    0    1
# 2018-01-01 02:00:00  1463.6552     2      1    0    1
# 2018-01-01 03:00:00  1413.1208     3      1    0    1
# 2018-01-01 04:00:00  1385.8796     4      1    0    1
# ...                        ...   ...    ...  ...  ...
# 2018-12-31 19:00:00  2528.4468    19     12    0  365
# 2018-12-31 20:00:00  2461.8836    20     12    0  365
# 2018-12-31 21:00:00  2365.9944    21     12    0  365
# 2018-12-31 22:00:00  2342.9428    22     12    0  365
# 2018-12-31 23:00:00  2180.2176    23     12    0  365
#
# [8760 rows x 5 columns]

# %%
y_train=x_train['energy'].reset_index().drop("datetime",axis=1)
y_test=x_test["energy"].reset_index().drop("datetime",axis=1)

# %%
y_train=y_train['energy']
y_test=y_test['energy']

# %%
x_train=x_train.drop('energy', axis=1)
x_test=x_test.drop('energy', axis=1)

# %%
model=RandomForestRegressor(n_estimators=1000,random_state=42, n_jobs=-1)
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=1000, n_jobs=-1, random_state=42)

# %%
from sklearn.metrics import r2_score

# %%
predicted_test=model.predict(x_train)
predicted_train=model.predict(x_test)

# %%
print("train", r2_score(y_train,predicted_test))
print("test", r2_score(y_test,predicted_train))
# Out:
# train 0.6751451620527588
# test -0.8027235103558341

# %%
x_train
# Out:
#                      hour  month  dow  doy
# datetime
# 2008-03-01 00:00:00     0      3    5   61
# 2008-03-01 01:00:00     1      3    5   61
# 2008-03-01 02:00:00     2      3    5   61
# 2008-03-01 03:00:00     3      3    5   61
# 2008-03-01 04:00:00     4      3    5   61
# ...                   ...    ...  ...  ...
# 2017-12-31 19:00:00    19     12    6  365
# 2017-12-31 20:00:00    20     12    6  365
# 2017-12-31 21:00:00    21     12    6  365
# 2017-12-31 22:00:00    22     12    6  365
# 2017-12-31 23:00:00    23     12    6  365
#
# [86232 rows x 4 columns]

# %%
plt.figure(figsize=(20,15))
sns.lineplot(y_test)
sns.lineplot(predicted_train)
plt.show()
